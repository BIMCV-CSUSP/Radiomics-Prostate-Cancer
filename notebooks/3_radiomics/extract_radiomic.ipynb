# %% [markdown]
# # Falta por hacer

# %% [markdown]
# - Imagen completa ¿?
# - Transformaciones
# - Imagen concatenada

# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm 

from radiomics import featureextractor
import SimpleITK as sitk

# %%
import logging

logging.getLogger('radiomics').setLevel(logging.CRITICAL)

# %% [markdown]
# # Initial configuration

# %%
input_csv = "../../../data/data.csv"
pre_path = "../../../"

t2_features_gland_csv      = "features_t2_gland.csv"
t2_features_full_csv       = "features_t2_full.csv"
adc_features_gland_csv     = "features_adc_gland.csv"
adc_features_full_csv      = "features_adc_full.csv"
dwi_features_gland_csv     = "features_dwi_gland.csv"
dwi_features_full_csv      = "features_dwi_full.csv"
composite_features_gland_csv = "features_composite_gland.csv"
composite_features_full_csv  = "features_composite_full.csv"

extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.settings['geometryTolerance'] = 1e-4
extractor.settings['binWidth'] = 25

# %% [markdown]
# # Functions

# %%
def resample_to_reference(moving_image, reference_image, is_mask=False):
    """
    Reamuestra 'moving_image' (sitk.Image) a la geometría de 'reference_image'.
    Si 'is_mask' es True, usa interpolación 'NearestNeighbor' (para mantener etiquetas enteras).
    De lo contrario, usa interpolación 'Linear'.
    """
    resample = sitk.ResampleImageFilter()
    resample.SetReferenceImage(reference_image)
    
    if is_mask:
        resample.SetInterpolator(sitk.sitkNearestNeighbor)
    else:
        resample.SetInterpolator(sitk.sitkLinear)
    
    resampled = resample.Execute(moving_image)
    return resampled

# %%
def preprocess_image(image):
    """
    Aplica preprocesamiento a la imagen:
      - Corrección de ruido (denoising) usando un filtro de flujo de curvatura.
      - Corrección de no uniformidad (bias field correction) usando N4BiasFieldCorrection.
    """
    # 1. Denoising: usamos el filtro de flujo de curvatura
    curvatureFilter = sitk.CurvatureFlowImageFilter()
    curvatureFilter.SetTimeStep(0.125)
    curvatureFilter.SetNumberOfIterations(5)
    denoised = curvatureFilter.Execute(image)
    
    # 2. Corrección de no uniformidad:
    #    Se crea una máscara inicial de la imagen mediante un umbral de Otsu.
    mask = sitk.OtsuThreshold(denoised, 0, 1, 200)
    corrected = sitk.N4BiasFieldCorrection(denoised, mask)
    
    return corrected

# %%
def extract_radiomic_features_from_sitk(image_sitk, mask_path, patient_id, study_id, label_value, mask_type="gland"):
    """
    Extrae características radiómicas a partir de una imagen (sitk.Image) ya preprocesada.
    Permite elegir entre extraer las características sobre:
      - La glándula (usando la máscara proporcionada, mask_type="gland")
      - La imagen completa (mask_type="full")
    """
    if mask_type == "gland":
        mask_sitk = sitk.ReadImage(mask_path)
        mask_sitk = resample_to_reference(mask_sitk, image_sitk, is_mask=True)
    elif mask_type == "full":
        mask_sitk = sitk.Image(image_sitk.GetSize(), sitk.sitkUInt8)
        mask_sitk.CopyInformation(image_sitk)
        mask_sitk = sitk.Add(mask_sitk, 1)
    else:
        raise ValueError("mask_type debe ser 'gland' o 'full'")
    
    features = extractor.execute(image_sitk, mask_sitk)
    
    out_dict = {
        "patient_id": patient_id,
        "study_id": study_id,
        "label": label_value,
        "mask_type": mask_type
    }
    
    for k, v in features.items():
        if k.startswith("original_"):
            out_dict[k] = v
    
    return out_dict

# %%
def extract_radiomic_features(image_path, mask_path, patient_id, study_id, label_value, mask_type="gland"):
    """
    Carga la imagen desde 'image_path', le aplica preprocesamiento y extrae las características.
    """
    image_sitk = sitk.ReadImage(image_path)
    image_sitk = preprocess_image(image_sitk)
    
    return extract_radiomic_features_from_sitk(image_sitk, mask_path, patient_id, study_id, label_value, mask_type)

# %% [markdown]
# # "Main"

# %%
df = pd.read_csv(input_csv)

t2_features_gland  = []
# t2_features_full   = []
adc_features_gland = []
# adc_features_full  = []
dwi_features_gland = []
# dwi_features_full  = []
composite_features_gland = []
# composite_features_full  = []

for idx, row in tqdm(df.iterrows(), total=len(df), desc="Procesando imágenes"):
    patient_id = row["patient_id"]
    study_id   = row["study_id"]
    label_val  = row["case_csPCa"]
    
    gland_mask_path = os.path.join(pre_path, row["whole_gland_path"])
    
    # ----- Procesamiento de T2 -----
    t2_img_path = os.path.join(pre_path, row["t2w_path"])
    if os.path.isfile(t2_img_path) and os.path.isfile(gland_mask_path):
        feats_t2_gland = extract_radiomic_features(
            image_path=t2_img_path,
            mask_path=gland_mask_path,
            patient_id=patient_id,
            study_id=study_id,
            label_value=label_val,
            mask_type="gland"
        )
        t2_features_gland.append(feats_t2_gland)
        
        # feats_t2_full = extract_radiomic_features(
        #     image_path=t2_img_path,
        #     mask_path=gland_mask_path,  
        #     patient_id=patient_id,
        #     study_id=study_id,
        #     label_value=label_val,
        #     mask_type="full"
        # )
        # t2_features_full.append(feats_t2_full)
    
    # ----- Procesamiento de ADC -----
    adc_img_path = os.path.join(pre_path, row["adc_path"])
    if os.path.isfile(adc_img_path) and os.path.isfile(gland_mask_path):
        feats_adc_gland = extract_radiomic_features(
            image_path=adc_img_path,
            mask_path=gland_mask_path,
            patient_id=patient_id,
            study_id=study_id,
            label_value=label_val,
            mask_type="gland"
        )
        adc_features_gland.append(feats_adc_gland)
        
        # feats_adc_full = extract_radiomic_features(
        #     image_path=adc_img_path,
        #     mask_path=gland_mask_path,
        #     patient_id=patient_id,
        #     study_id=study_id,
        #     label_value=label_val,
        #     mask_type="full"
        # )
        # adc_features_full.append(feats_adc_full)
    
    # ----- Procesamiento de DWI -----
    dwi_img_path = os.path.join(pre_path, row["hbv_path"])
    if os.path.isfile(dwi_img_path) and os.path.isfile(gland_mask_path):
        feats_dwi_gland = extract_radiomic_features(
            image_path=dwi_img_path,
            mask_path=gland_mask_path,
            patient_id=patient_id,
            study_id=study_id,
            label_value=label_val,
            mask_type="gland"
        )
        dwi_features_gland.append(feats_dwi_gland)
        
        # feats_dwi_full = extract_radiomic_features(
        #     image_path=dwi_img_path,
        #     mask_path=gland_mask_path,
        #     patient_id=patient_id,
        #     study_id=study_id,
        #     label_value=label_val,
        #     mask_type="full"
        # )
        # dwi_features_full.append(feats_dwi_full)
    
    # ----- Procesamiento de imagen compuesta -----
    # Si existen las tres modalidades, se crea una imagen compuesta promedio)
    if (os.path.isfile(t2_img_path) and os.path.isfile(adc_img_path) and os.path.isfile(dwi_img_path) 
        and os.path.isfile(gland_mask_path)):
    
        t2_image = preprocess_image(sitk.ReadImage(t2_img_path))
        adc_image = preprocess_image(sitk.ReadImage(adc_img_path))
        dwi_image = preprocess_image(sitk.ReadImage(dwi_img_path))
        
        adc_image_rs = resample_to_reference(adc_image, t2_image, is_mask=False)
        dwi_image_rs = resample_to_reference(dwi_image, t2_image, is_mask=False)
        
        t2_arr = sitk.GetArrayFromImage(t2_image).astype(np.float32)
        adc_arr = sitk.GetArrayFromImage(adc_image_rs).astype(np.float32)
        dwi_arr = sitk.GetArrayFromImage(dwi_image_rs).astype(np.float32)
        
        composite_arr = (t2_arr + adc_arr + dwi_arr) / 3.0
        composite_image = sitk.GetImageFromArray(composite_arr)
        composite_image.CopyInformation(t2_image)
        
        feats_comp_gland = extract_radiomic_features_from_sitk(
            composite_image, gland_mask_path, patient_id, study_id, label_val, mask_type="gland"
        )
        composite_features_gland.append(feats_comp_gland)
        
        # feats_comp_full = extract_radiomic_features_from_sitk(
        #     composite_image, gland_mask_path, patient_id, study_id, label_val, mask_type="full"
        # )
        # composite_features_full.append(feats_comp_full)
# Out:
# Procesando imágenes:   0%|▏                                                        | 4/1500 [11:42<73:00:20, 175.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4882/2170777498.py in ?()
#      89         # feats_dwi_full = extract_radiomic_features(
#      90         #     image_path=dwi_img_path,
#      91         #     mask_path=gland_mask_path,
#      92         #     patient_id=patient_id,
# ---> 93         #     study_id=study_id,
#      94         #     label_value=label_val,
#      95         #     mask_type="full"
#      96         # )
#
# /tmp/ipykernel_4882/2550669086.py in ?(image)
#      12
#      13     # 2. Corrección de no uniformidad:
#      14     #    Se crea una máscara inicial de la imagen mediante un umbral de Otsu.
#      15     mask = sitk.OtsuThreshold(denoised, 0, 1, 200)
# ---> 16     corrected = sitk.N4BiasFieldCorrection(denoised, mask)
#      17
#      18     return corrected
#
# ~/anaconda3/envs/tfg/lib/python3.9/site-packages/SimpleITK/SimpleITK.py in ?(*args)
#   43077     r"""
#   43078     N4BiasFieldCorrection(Image image, Image maskImage, double convergenceThreshold=0.001, VectorUInt32 maximumNumberOfIterations=std::vector< uint32_t >(4,50), double biasFieldFullWidthAtHalfMaximum=0.15, double wienerFilterNoise=0.01, uint32_t numberOfHistogramBins=200, VectorUInt32 numberOfControlPoints=std::vector< uint32_t >(3, 4), uint32_t splineOrder=3, bool useMaskLabel=True, uint8_t maskLabel=1) -> Image
#   43079     N4BiasFieldCorrection(Image image, double convergenceThreshold=0.001, VectorUInt32 maximumNumberOfIterations=std::vector< uint32_t >(4,50), double biasFieldFullWidthAtHalfMaximum=0.15, double wienerFilterNoise=0.01, uint32_t numberOfHistogramBins=200, VectorUInt32 numberOfControlPoints=std::vector< uint32_t >(3, 4), uint32_t splineOrder=3, bool useMaskLabel=True, uint8_t maskLabel=1) -> Image
#   43080     """
# > 43081     return _SimpleITK.N4BiasFieldCorrection(*args)
#
# KeyboardInterrupt:

# %%
t2_features_gland  = []
t2_features_full   = []
adc_features_gland = []
adc_features_full  = []
dwi_features_gland = []
dwi_features_full  = []
composite_features_gland = []
composite_features_full  = []
# Out:
# 24

# %%
composite_features_gland
# Out:
# [{'patient_id': 10000,
#   'study_id': 1000000,
#   'label': 0,
#   'mask_type': 'gland',
#   'original_shape_Elongation': 0.8117099089996536,
#   'original_shape_Flatness': 0.6388960967418924,
#   'original_shape_LeastAxisLength': 29.458350250393444,
#   'original_shape_MajorAxisLength': 46.1082019449155,
#   'original_shape_Maximum2DDiameterColumn': array(51.75),
#   'original_shape_Maximum2DDiameterRow': array(46.40253376),
#   'original_shape_Maximum2DDiameterSlice': array(51.89958002),
#   'original_shape_Maximum3DDiameter': array(51.89958002),
#   'original_shape_MeshVolume': array(35678.30672058),
#   'original_shape_MinorAxisLength': 37.42648440484501,
#   'original_shape_Sphericity': array(0.75136869),
#   'original_shape_SurfaceArea': array(6975.36901054),
#   'original_shape_SurfaceVolumeRatio': array(0.19550729),
#   'original_shape_VoxelVolume': 35708.30401048427,
#   'original_firstorder_10Percentile': array(-704.39014893),
#   'original_firstorder_90Percentile': array(1548.02653809),
#   'original_firstorder_Energy': array(1.76954482e+11),
#   'original_firstorder_Entropy': array(7.29999254),
#   'original_firstorder_InterquartileRange': array(1001.03857803),
#   'original_firstorder_Kurtosis': array(8.78674941),
#   'original_firstorder_Maximum': array(12559.35253906),
#   'original_firstorder_MeanAbsoluteDeviation': array(729.78626703),
#   'original_firstorder_Mean': array(412.56931319),
#   'original_firstorder_Median': array(400.40124512),
#   'original_firstorder_Minimum': array(-10723.31933594),
#   'original_firstorder_Range': array(23282.671875),
#   'original_firstorder_RobustMeanAbsoluteDeviation': array(430.7250162),
#   'original_firstorder_RootMeanSquared': array(1137.35403266),
#   'original_firstorder_Skewness': array(0.10197801),
#   'original_firstorder_TotalEnergy': array(4.61913406e+10),
#   'original_firstorder_Uniformity': array(0.00863537),
#   'original_firstorder_Variance': array(1123360.7574238),
#   'original_glcm_Autocorrelation': array(198817.94709287),
#   'original_glcm_ClusterProminence': array(97488298.55109169),
#   'original_glcm_ClusterShade': array(20929.3663249),
#   'original_glcm_ClusterTendency': array(3394.68017857),
#   'original_glcm_Contrast': array(3557.85328007),
#   'original_glcm_Correlation': array(-0.02259131),
#   'original_glcm_DifferenceAverage': array(41.77079921),
#   'original_glcm_DifferenceEntropy': array(6.80379037),
#   'original_glcm_DifferenceVariance': array(1763.45985713),
#   'original_glcm_Id': array(0.07381339),
#   'original_glcm_Idm': array(0.03033301),
#   'original_glcm_Idmn': array(0.99603157),
#   'original_glcm_Idn': array(0.95876608),
#   'original_glcm_Imc1': array(-0.05720288),
#   'original_glcm_Imc2': array(0.72490189),
#   'original_glcm_InverseVariance': array(0.03162929),
#   'original_glcm_JointAverage': array(445.93580026),
#   'original_glcm_JointEnergy': array(9.58710318e-05),
#   'original_glcm_JointEntropy': array(14.14265898),
#   'original_glcm_MCC': array(0.66347408),
#   'original_glcm_MaximumProbability': array(0.00035869),
#   'original_glcm_SumAverage': array(891.87160051),
#   'original_glcm_SumEntropy': array(7.7229262),
#   'original_glcm_SumSquares': array(1738.13336466),
#   'original_gldm_DependenceEntropy': array(8.10075126),
#   'original_gldm_DependenceNonUniformity': array(91431.74847765),
#   'original_gldm_DependenceNonUniformityNormalized': array(0.66838516),
#   'original_gldm_DependenceVariance': array(0.25743809),
#   'original_gldm_GrayLevelNonUniformity': array(1181.27512701),
#   'original_gldm_GrayLevelVariance': array(1797.34359497),
#   'original_gldm_HighGrayLevelEmphasis': array(200715.66497313),
#   'original_gldm_LargeDependenceEmphasis': array(1.78286487),
#   'original_gldm_LargeDependenceHighGrayLevelEmphasis': array(356424.79552615),
#   'original_gldm_LargeDependenceLowGrayLevelEmphasis': array(1.64721469e-05),
#   'original_gldm_LowGrayLevelEmphasis': array(1.2499997e-05),
#   'original_gldm_SmallDependenceEmphasis': array(0.84491483),
#   'original_gldm_SmallDependenceHighGrayLevelEmphasis': array(169837.50993948),
#   'original_gldm_SmallDependenceLowGrayLevelEmphasis': array(1.17128584e-05),
#   'original_glrlm_GrayLevelNonUniformity': array(1164.18086165),
#   'original_glrlm_GrayLevelNonUniformityNormalized': array(0.00858805),
#   'original_glrlm_GrayLevelVariance': array(1809.40615309),
#   'original_glrlm_HighGrayLevelRunEmphasis': array(200731.46813595),
#   'original_glrlm_LongRunEmphasis': array(1.02763561),
#   'original_glrlm_LongRunHighGrayLevelEmphasis': array(206230.3103627),
#   'original_glrlm_LongRunLowGrayLevelEmphasis': array(1.27080329e-05),
#   'original_glrlm_LowGrayLevelRunEmphasis': array(1.25677937e-05),
#   'original_glrlm_RunEntropy': array(7.37689163),
#   'original_glrlm_RunLengthNonUniformity': array(133140.54775848),
#   'original_glrlm_RunLengthNonUniformityNormalized': array(0.98215341),
#   'original_glrlm_RunPercentage': array(0.9909584),
#   'original_glrlm_RunVariance': array(0.00928493),
#   'original_glrlm_ShortRunEmphasis': array(0.99322622),
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': array(199383.50798296),
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': array(1.2533419e-05),
#   'original_glszm_GrayLevelNonUniformity': array(976.07374991),
#   'original_glszm_GrayLevelNonUniformityNormalized': array(0.00803677),
#   'original_glszm_GrayLevelVariance': array(1962.32766677),
#   'original_glszm_HighGrayLevelZoneEmphasis': array(200927.26725181),
#   'original_glszm_LargeAreaEmphasis': array(1.45152366),
#   'original_glszm_LargeAreaHighGrayLevelEmphasis': array(290742.86887716),
#   'original_glszm_LargeAreaLowGrayLevelEmphasis': array(1.57286313e-05),
#   'original_glszm_LowGrayLevelZoneEmphasis': array(1.34380914e-05),
#   'original_glszm_SizeZoneNonUniformity': array(99183.87273057),
#   'original_glszm_SizeZoneNonUniformityNormalized': array(0.81665752),
#   'original_glszm_SmallAreaEmphasis': array(0.92200394),
#   'original_glszm_SmallAreaHighGrayLevelEmphasis': array(185389.68023747),
#   'original_glszm_SmallAreaLowGrayLevelEmphasis': array(1.30421328e-05),
#   'original_glszm_ZoneEntropy': array(7.91071285),
#   'original_glszm_ZonePercentage': array(0.88783216),
#   'original_glszm_ZoneVariance': array(0.18288408),
#   'original_ngtdm_Busyness': array(0.04408322),
#   'original_ngtdm_Coarseness': array(5.37750085e-05),
#   'original_ngtdm_Complexity': array(4937137.94612786),
#   'original_ngtdm_Contrast': array(0.31304314),
#   'original_ngtdm_Strength': array(9.78810906)},
#  {'patient_id': 10001,
#   'study_id': 1000001,
#   'label': 0,
#   'mask_type': 'gland',
#   'original_shape_Elongation': 0.8689635595378453,
#   'original_shape_Flatness': 0.7649257244735923,
#   'original_shape_LeastAxisLength': 43.94986489242242,
#   'original_shape_MajorAxisLength': 57.45638234701533,
#   'original_shape_Maximum2DDiameterColumn': array(64.51046578),
#   'original_shape_Maximum2DDiameterRow': array(65.20498602),
#   'original_shape_Maximum2DDiameterSlice': array(62.65477086),
#   'original_shape_Maximum3DDiameter': array(68.48416048),
#   'original_shape_MeshVolume': array(89627.27856207),
#   'original_shape_MinorAxisLength': 49.92750252242986,
#   'original_shape_Sphericity': array(0.74319532),
#   'original_shape_SurfaceArea': array(13031.90683021),
#   'original_shape_SurfaceVolumeRatio': array(0.14540112),
#   'original_shape_VoxelVolume': 89674.46106685472,
#   'original_firstorder_10Percentile': array(-115.91147919),
#   'original_firstorder_90Percentile': array(1174.76953125),
#   'original_firstorder_Energy': array(1.67659223e+11),
#   'original_firstorder_Entropy': array(6.46745902),
#   'original_firstorder_InterquartileRange': array(583.3313446),
#   'original_firstorder_Kurtosis': array(6.73509002),
#   'original_firstorder_Maximum': array(6808.68701172),
#   'original_firstorder_MeanAbsoluteDeviation': array(408.37696073),
#   'original_firstorder_Mean': array(528.85410214),
#   'original_firstorder_Median': array(528.40802002),
#   'original_firstorder_Minimum': array(-5582.04882812),
#   'original_firstorder_Range': array(12390.73583984),
#   'original_firstorder_RobustMeanAbsoluteDeviation': array(250.18450728),
#   'original_firstorder_RootMeanSquared': array(778.30866107),
#   'original_firstorder_Skewness': array(0.03518929),
#   'original_firstorder_TotalEnergy': array(5.43215936e+10),
#   'original_firstorder_Uniformity': array(0.01493851),
#   'original_firstorder_Variance': array(326077.71055465),
#   'original_glcm_Autocorrelation': array(60328.06404894),
#   'original_glcm_ClusterProminence': array(6993008.01251676),
#   'original_glcm_ClusterShade': array(1525.86269056),
#   'original_glcm_ClusterTendency': array(1027.83214444),
#   'original_glcm_Contrast': array(1058.82004657),
#   'original_glcm_Correlation': array(-0.01489458),
#   'original_glcm_DifferenceAverage': array(23.54000624),
#   'original_glcm_DifferenceEntropy': array(5.97959585),
#   'original_glcm_DifferenceVariance': array(487.88037981),
#   'original_glcm_Id': array(0.10904567),
#   'original_glcm_Idm': array(0.05090827),
#   'original_glcm_Idmn': array(0.99582537),
#   'original_glcm_Idn': array(0.95641754),
#   'original_glcm_Imc1': array(-0.03092956),
#   'original_glcm_Imc2': array(0.48974757),
#   'original_glcm_InverseVariance': array(0.05312587),
#   'original_glcm_JointAverage': array(245.63348878),
#   'original_glcm_JointEnergy': array(0.00026274),
#   'original_glcm_JointEntropy': array(12.73582558),
#   'original_glcm_MCC': array(0.45467566),
#   'original_glcm_MaximumProbability': array(0.00083169),
#   'original_glcm_SumAverage': array(491.26697756),
#   'original_glcm_SumEntropy': array(6.91212212),
#   'original_glcm_SumSquares': array(521.66304775),
#   'original_gldm_DependenceEntropy': array(7.59400474),
#   'original_gldm_DependenceNonUniformity': array(146424.68761404),
#   'original_gldm_DependenceNonUniformityNormalized': array(0.52904253),
#   'original_gldm_DependenceVariance': array(0.46460524),
#   'original_gldm_GrayLevelNonUniformity': array(4134.57495131),
#   'original_gldm_GrayLevelVariance': array(521.81276107),
#   'original_gldm_HighGrayLevelEmphasis': array(60867.66578749),
#   'original_gldm_LargeDependenceEmphasis': array(2.44793025),
#   'original_gldm_LargeDependenceHighGrayLevelEmphasis': array(148388.68416717),
#   'original_gldm_LargeDependenceLowGrayLevelEmphasis': array(4.49507027e-05),
#   'original_gldm_LowGrayLevelEmphasis': array(2.07435003e-05),
#   'original_gldm_SmallDependenceEmphasis': array(0.75099054),
#   'original_gldm_SmallDependenceHighGrayLevelEmphasis': array(45806.25791026),
#   'original_gldm_SmallDependenceLowGrayLevelEmphasis': array(1.65726908e-05),
#   'original_glrlm_GrayLevelNonUniformity': array(4034.61669791),
#   'original_glrlm_GrayLevelNonUniformityNormalized': array(0.01480993),
#   'original_glrlm_GrayLevelVariance': array(527.42641301),
#   'original_glrlm_HighGrayLevelRunEmphasis': array(60874.14152589),
#   'original_glrlm_LongRunEmphasis': array(1.04865822),
#   'original_glrlm_LongRunHighGrayLevelEmphasis': array(63816.0712863),
#   'original_glrlm_LongRunLowGrayLevelEmphasis': array(2.16216513e-05),
#   'original_glrlm_LowGrayLevelRunEmphasis': array(2.08075777e-05),
#   'original_glrlm_RunEntropy': array(6.5901225),
#   'original_glrlm_RunLengthNonUniformity': array(264068.26485768),
#   'original_glrlm_RunLengthNonUniformityNormalized': array(0.96928573),
#   'original_glrlm_RunPercentage': array(0.98429593),
#   'original_glrlm_RunVariance': array(0.01643918),
#   'original_glrlm_ShortRunEmphasis': array(0.98824174),
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': array(60163.19777758),
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': array(2.06108196e-05),
#   'original_glszm_GrayLevelNonUniformity': array(2992.06166549),
#   'original_glszm_GrayLevelNonUniformityNormalized': array(0.01332565),
#   'original_glszm_GrayLevelVariance': array(601.58307178),
#   'original_glszm_HighGrayLevelZoneEmphasis': array(60960.28897628),
#   'original_glszm_LargeAreaEmphasis': array(1.95715126),
#   'original_glszm_LargeAreaHighGrayLevelEmphasis': array(118810.17586201),
#   'original_glszm_LargeAreaLowGrayLevelEmphasis': array(3.76720737e-05),
#   'original_glszm_LowGrayLevelZoneEmphasis': array(2.16750321e-05),
#   'original_glszm_SizeZoneNonUniformity': array(162099.46076763),
#   'original_glszm_SizeZoneNonUniformityNormalized': array(0.72193726),
#   'original_glszm_SmallAreaEmphasis': array(0.87388877),
#   'original_glszm_SmallAreaHighGrayLevelEmphasis': array(53328.94766525),
#   'original_glszm_SmallAreaLowGrayLevelEmphasis': array(1.95602309e-05),
#   'original_glszm_ZoneEntropy': array(7.38863837),
#   'original_glszm_ZonePercentage': array(0.81125688),
#   'original_glszm_ZoneVariance': array(0.43771244),
#   'original_ngtdm_Busyness': array(0.27687878),
#   'original_ngtdm_Coarseness': array(2.61669726e-05),
#   'original_ngtdm_Complexity': array(969270.11327887),
#   'original_ngtdm_Contrast': array(0.14623353),
#   'original_ngtdm_Strength': array(1.74955652)},
#  {'patient_id': 10002,
#   'study_id': 1000002,
#   'label': 0,
#   'mask_type': 'gland',
#   'original_shape_Elongation': 0.9830170764402445,
#   'original_shape_Flatness': 0.8202891786592301,
#   'original_shape_LeastAxisLength': 40.42431004349382,
#   'original_shape_MajorAxisLength': 49.28055994785609,
#   'original_shape_Maximum2DDiameterColumn': array(55.58102195),
#   'original_shape_Maximum2DDiameterRow': array(58.79625904),
#   'original_shape_Maximum2DDiameterSlice': array(55.73149917),
#   'original_shape_Maximum3DDiameter': array(59.71599515),
#   'original_shape_MeshVolume': array(68627.65798708),
#   'original_shape_MinorAxisLength': 48.4436319652797,
#   'original_shape_Sphericity': array(0.79661052),
#   'original_shape_SurfaceArea': array(10175.85409541),
#   'original_shape_SurfaceVolumeRatio': array(0.14827628),
#   'original_shape_VoxelVolume': 68688.75173862805,
#   'original_firstorder_10Percentile': array(214.96903076),
#   'original_firstorder_90Percentile': array(732.43779297),
#   'original_firstorder_Energy': array(2.96655532e+10),
#   'original_firstorder_Entropy': array(4.55348936),
#   'original_firstorder_InterquartileRange': array(169.84127808),
#   'original_firstorder_Kurtosis': array(3.24754689),
#   'original_firstorder_Maximum': array(981.02056885),
#   'original_firstorder_MeanAbsoluteDeviation': array(137.07154682),
#   'original_firstorder_Mean': array(539.28449548),
#   'original_firstorder_Median': array(578.24591064),
#   'original_firstorder_Minimum': array(42.46746445),
#   'original_firstorder_Range': array(938.5531044),
#   'original_firstorder_RobustMeanAbsoluteDeviation': array(87.11944988),
#   'original_firstorder_RootMeanSquared': array(569.13337065),
#   'original_firstorder_Skewness': array(-0.95558514),
#   'original_firstorder_TotalEnergy': array(2.22491655e+10),
#   'original_firstorder_Uniformity': array(0.05263831),
#   'original_firstorder_Variance': array(33085.02652178),
#   'original_glcm_Autocorrelation': array(498.34909982),
#   'original_glcm_ClusterProminence': array(129424.47736581),
#   'original_glcm_ClusterShade': array(-2745.78598867),
#   'original_glcm_ClusterTendency': array(191.6206458),
#   'original_glcm_Contrast': array(10.80078212),
#   'original_glcm_Correlation': array(0.89192005),
#   'original_glcm_DifferenceAverage': array(2.00170381),
#   'original_glcm_DifferenceEntropy': array(2.56716423),
#   'original_glcm_DifferenceVariance': array(6.25706489),
#   'original_glcm_Id': array(0.51344554),
#   'original_glcm_Idm': array(0.45792212),
#   'original_glcm_Idmn': array(0.9934201),
#   'original_glcm_Idn': array(0.95444333),
#   'original_glcm_Imc1': array(-0.29917175),
#   'original_glcm_Imc2': array(0.94611614),
#   'original_glcm_InverseVariance': array(0.39404429),
#   'original_glcm_JointAverage': array(21.28696109),
#   'original_glcm_JointEnergy': array(0.00863717),
#   'original_glcm_JointEntropy': array(7.69208784),
#   'original_glcm_MCC': array(0.90885624),
#   'original_glcm_MaximumProbability': array(0.02115547),
#   'original_glcm_SumAverage': array(42.57392218),
#   'original_glcm_SumEntropy': array(5.47323457),
#   'original_glcm_SumSquares': array(50.60535698),
#   'original_gldm_DependenceEntropy': array(8.34898845),
#   'original_gldm_DependenceNonUniformity': array(7097.67991483),
#   'original_gldm_DependenceNonUniformityNormalized': array(0.07749828),
#   'original_gldm_DependenceVariance': array(15.6619912),
#   'original_gldm_GrayLevelNonUniformity': array(4820.87939073),
#   'original_gldm_GrayLevelVariance': array(53.02728307),
#   'original_gldm_HighGrayLevelEmphasis': array(496.98370912),
#   'original_gldm_LargeDependenceEmphasis': array(63.33627777),
#   'original_gldm_LargeDependenceHighGrayLevelEmphasis': array(30222.30309549),
#   'original_gldm_LargeDependenceLowGrayLevelEmphasis': array(0.6131452),
#   'original_gldm_LowGrayLevelEmphasis': array(0.00760603),
#   'original_gldm_SmallDependenceEmphasis': array(0.08610375),
#   'original_gldm_SmallDependenceHighGrayLevelEmphasis': array(39.07003701),
#   'original_gldm_SmallDependenceLowGrayLevelEmphasis': array(0.00061546),
#   'original_glrlm_GrayLevelNonUniformity': array(3709.6190209),
#   'original_glrlm_GrayLevelNonUniformityNormalized': array(0.05235924),
#   'original_glrlm_GrayLevelVariance': array(51.8072043),
#   'original_glrlm_HighGrayLevelRunEmphasis': array(498.52029886),
#   'original_glrlm_LongRunEmphasis': array(2.41579909),
#   'original_glrlm_LongRunHighGrayLevelEmphasis': array(1189.31919403),
#   'original_glrlm_LongRunLowGrayLevelEmphasis': array(0.01970239),
#   'original_glrlm_LowGrayLevelRunEmphasis': array(0.00727387),
#   'original_glrlm_RunEntropy': array(5.54018045),
#   'original_glrlm_RunLengthNonUniformity': array(47925.94772391),
#   'original_glrlm_RunLengthNonUniformityNormalized': array(0.66080451),
#   'original_glrlm_RunPercentage': array(0.77289781),
#   'original_glrlm_RunVariance': array(0.6224052),
#   'original_glrlm_ShortRunEmphasis': array(0.83464125),
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': array(416.45271739),
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': array(0.00587685),
#   'original_glszm_GrayLevelNonUniformity': array(252.28624079),
#   'original_glszm_GrayLevelNonUniformityNormalized': array(0.03874174),
#   'original_glszm_GrayLevelVariance': array(51.65276916),
#   'original_glszm_HighGrayLevelZoneEmphasis': array(417.6122543),
#   'original_glszm_LargeAreaEmphasis': array(42660.11993243),
#   'original_glszm_LargeAreaHighGrayLevelEmphasis': array(22049573.57109951),
#   'original_glszm_LargeAreaLowGrayLevelEmphasis': array(161.39416188),
#   'original_glszm_LowGrayLevelZoneEmphasis': array(0.00733127),
#   'original_glszm_SizeZoneNonUniformity': array(2073.63789926),
#   'original_glszm_SizeZoneNonUniformityNormalized': array(0.31843334),
#   'original_glszm_SmallAreaEmphasis': array(0.58091071),
#   'original_glszm_SmallAreaHighGrayLevelEmphasis': array(237.23541329),
#   'original_glszm_SmallAreaLowGrayLevelEmphasis': array(0.00443362),
#   'original_glszm_ZoneEntropy': array(7.18061172),
#   'original_glszm_ZonePercentage': array(0.07110335),
#   'original_glszm_ZoneVariance': array(42462.32283433),
#   'original_ngtdm_Busyness': array(5.4648993),
#   'original_ngtdm_Coarseness': array(0.00017942),
#   'original_ngtdm_Complexity': array(817.46494857),
#   'original_ngtdm_Contrast': array(0.09243776),
#   'original_ngtdm_Strength': array(0.11923264)},
#  {'patient_id': 10003,
#   'study_id': 1000003,
#   'label': 0,
#   'mask_type': 'gland',
#   'original_shape_Elongation': 0.9630900612378447,
#   'original_shape_Flatness': 0.8200391139771993,
#   'original_shape_LeastAxisLength': 41.35930474468158,
#   'original_shape_MajorAxisLength': 50.43577073304281,
#   'original_shape_Maximum2DDiameterColumn': array(53.77034521),
#   'original_shape_Maximum2DDiameterRow': array(61.29437282),
#   'original_shape_Maximum2DDiameterSlice': array(55.97320788),
#   'original_shape_Maximum3DDiameter': array(61.45933728),
#   'original_shape_MeshVolume': array(72353.06443768),
#   'original_shape_MinorAxisLength': 48.57418952386409,
#   'original_shape_Sphericity': array(0.79192047),
#   'original_shape_SurfaceArea': array(10603.28682335),
#   'original_shape_SurfaceVolumeRatio': array(0.14654924),
#   'original_shape_VoxelVolume': 72416.25193935887,
#   'original_firstorder_10Percentile': array(495.17506104),
#   'original_firstorder_90Percentile': array(681.78594971),
#   'original_firstorder_Energy': array(3.3127896e+10),
#   'original_firstorder_Entropy': array(3.65057288),
#   'original_firstorder_InterquartileRange': array(93.81686401),
#   'original_firstorder_Kurtosis': array(6.38356637),
#   'original_firstorder_Maximum': array(1040.65808105),
#   'original_firstorder_MeanAbsoluteDeviation': array(60.21096404),
#   'original_firstorder_Mean': array(580.07427584),
#   'original_firstorder_Median': array(573.24719238),
#   'original_firstorder_Minimum': array(47.99026871),
#   'original_firstorder_Range': array(992.66781235),
#   'original_firstorder_RobustMeanAbsoluteDeviation': array(39.38973409),
#   'original_firstorder_RootMeanSquared': array(585.7462848),
#   'original_firstorder_Skewness': array(-0.00662658),
#   'original_firstorder_TotalEnergy': array(2.48459226e+10),
#   'original_firstorder_Uniformity': array(0.099807),
#   'original_firstorder_Variance': array(6612.54466366),
#   'original_glcm_Autocorrelation': array(524.07128223),
#   'original_glcm_ClusterProminence': array(6462.47669289),
#   'original_glcm_ClusterShade': array(31.92695776),
#   'original_glcm_ClusterTendency': array(33.96529646),
#   'original_glcm_Contrast': array(5.89313625),
#   'original_glcm_Correlation': array(0.70012882),
#   'original_glcm_DifferenceAverage': array(1.60144116),
#   'original_glcm_DifferenceEntropy': array(2.2778915),
#   'original_glcm_DifferenceVariance': array(2.90981158),
#   'original_glcm_Id': array(0.54736495),
#   'original_glcm_Idm': array(0.49653311),
#   'original_glcm_Idmn': array(0.9965916),
#   'original_glcm_Idn': array(0.96402361),
#   'original_glcm_Imc1': array(-0.21691229),
#   'original_glcm_Imc2': array(0.79801433),
#   'original_glcm_InverseVariance': array(0.40500872),
#   'original_glcm_JointAverage': array(22.73879872),
#   'original_glcm_JointEnergy': array(0.02066534),
#   'original_glcm_JointEntropy': array(6.44541448),
#   'original_glcm_MCC': array(0.71213973),
#   'original_glcm_MaximumProbability': array(0.04575599),
#   'original_glcm_SumAverage': array(45.47759743),
#   'original_glcm_SumEntropy': array(4.49897472),
#   'original_glcm_SumSquares': array(9.96460818),
#   'original_gldm_DependenceEntropy': array(7.52262537),
#   'original_gldm_DependenceNonUniformity': array(7047.85331676),
#   'original_gldm_DependenceNonUniformityNormalized': array(0.07299315),
#   'original_gldm_DependenceVariance': array(16.88303237),
#   'original_gldm_GrayLevelNonUniformity': array(9636.86500958),
#   'original_gldm_GrayLevelVariance': array(10.67124346),
#   'original_gldm_HighGrayLevelEmphasis': array(526.05787375),
#   'original_gldm_LargeDependenceEmphasis': array(77.39807364),
#   'original_gldm_LargeDependenceHighGrayLevelEmphasis': array(38975.79015069),
#   'original_gldm_LargeDependenceLowGrayLevelEmphasis': array(0.16261945),
#   'original_gldm_LowGrayLevelEmphasis': array(0.00221381),
#   'original_gldm_SmallDependenceEmphasis': array(0.05749621),
#   'original_gldm_SmallDependenceHighGrayLevelEmphasis': array(30.83794334),
#   'original_gldm_SmallDependenceLowGrayLevelEmphasis': array(0.0001874),
#   'original_glrlm_GrayLevelNonUniformity': array(6815.75474787),
#   'original_glrlm_GrayLevelNonUniformityNormalized': array(0.09512154),
#   'original_glrlm_GrayLevelVariance': array(11.9300807),
#   'original_glrlm_HighGrayLevelRunEmphasis': array(531.42814101),
#   'original_glrlm_LongRunEmphasis': array(3.06146369),
#   'original_glrlm_LongRunHighGrayLevelEmphasis': array(1580.21766097),
#   'original_glrlm_LongRunLowGrayLevelEmphasis': array(0.00659425),
#   'original_glrlm_LowGrayLevelRunEmphasis': array(0.00226183),
#   'original_glrlm_RunEntropy': array(4.8252814),
#   'original_glrlm_RunLengthNonUniformity': array(46451.12962251),
#   'original_glrlm_RunLengthNonUniformityNormalized': array(0.62040071),
#   'original_glrlm_RunPercentage': array(0.73926379),
#   'original_glrlm_RunVariance': array(0.93543172),
#   'original_glrlm_ShortRunEmphasis': array(0.80432032),
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': array(430.19042108),
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': array(0.001851),
#   'original_glszm_GrayLevelNonUniformity': array(166.1776),
#   'original_glszm_GrayLevelNonUniformityNormalized': array(0.04431403),
#   'original_glszm_GrayLevelVariance': array(44.56042958),
#   'original_glszm_HighGrayLevelZoneEmphasis': array(537.95706667),
#   'original_glszm_LargeAreaEmphasis': array(192938.3976),
#   'original_glszm_LargeAreaHighGrayLevelEmphasis': array(94708641.27306667),
#   'original_glszm_LargeAreaLowGrayLevelEmphasis': array(399.91477534),
#   'original_glszm_LowGrayLevelZoneEmphasis': array(0.00431392),
#   'original_glszm_SizeZoneNonUniformity': array(1007.55146667),
#   'original_glszm_SizeZoneNonUniformityNormalized': array(0.26868039),
#   'original_glszm_SmallAreaEmphasis': array(0.53289698),
#   'original_glszm_SmallAreaHighGrayLevelEmphasis': array(274.08745444),
#   'original_glszm_SmallAreaLowGrayLevelEmphasis': array(0.00248067),
#   'original_glszm_ZoneEntropy': array(7.41763132),
#   'original_glszm_ZonePercentage': array(0.03883797),
#   'original_glszm_ZoneVariance': array(192275.438096),
#   'original_ngtdm_Busyness': array(6.15443957),
#   'original_ngtdm_Coarseness': array(0.00011379),
#   'original_ngtdm_Complexity': array(861.43075616),
#   'original_ngtdm_Contrast': array(0.01425429),
#   'original_ngtdm_Strength': array(0.11906849)}]
