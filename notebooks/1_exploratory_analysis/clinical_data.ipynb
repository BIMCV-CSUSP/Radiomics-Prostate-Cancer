# %% [markdown]
# <h1 style="text-align:center;">Clinical data</h1>

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib as mpl
import scienceplots

plt.style.use(['science', 'grid'])

# %% [markdown]
# # Data

# %%
df = pd.read_csv("../../../data/labels/clinical_information/marksheet.csv")

# %%
df
# Out:
#       patient_id  study_id    mri_date  patient_age    psa  psad  \
# 0          10000   1000000  2019-07-02           73   7.70   NaN
# 1          10001   1000001  2016-05-27           64   8.70  0.09
# 2          10002   1000002  2021-04-18           58   4.20  0.06
# 3          10003   1000003  2019-04-05           72  13.00   NaN
# 4          10004   1000004  2020-10-21           67   8.00  0.10
# ...          ...       ...         ...          ...    ...   ...
# 1495       11471   1001495  2012-08-25           71  12.50  0.21
# 1496       11472   1001496  2019-06-28           81   5.28  0.12
# 1497       11473   1001497  2017-09-24           56  29.60  0.34
# 1498       11474   1001498  2016-05-03           71  12.00   NaN
# 1499       11475   1001499  2012-12-23           56  15.00  0.46
#
#       prostate_volume histopath_type    lesion_GS lesion_ISUP  case_ISUP  \
# 0                55.0           MRBx          0+0           0          0
# ...

# %%
df.loc[df.case_ISUP == 5]
# Out:
#       patient_id  study_id    mri_date  patient_age     psa  psad  \
# 29         10029   1000029  2017-10-15           64    8.90  0.20
# 94         10094   1000094  2019-03-26           62   10.24  0.27
# 134        10132   1000134  2019-09-28           67    5.00  0.22
# 171        10168   1000171  2019-03-04           66    5.90   NaN
# 185        10182   1000185  2018-08-13           77    6.80  0.12
# 215        10211   1000215  2012-02-13           63   17.90  0.52
# 218        10214   1000218  2019-06-07           71   11.00  0.09
# 240        10236   1000240  2019-12-08           74   36.00  1.10
# 288        10282   1000288  2018-11-20           61   18.00  0.37
# 318        10312   1000318  2020-12-04           72   31.00  0.70
# 345        10339   1000345  2012-02-29           64   23.00  0.36
# 348        10342   1000348  2016-03-20           70    2.30   NaN
# 377        10371   1000377  2018-09-07           65   27.00  0.37
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# ## General

# %%
df.describe()
# Out:
#          patient_id      study_id  patient_age          psa         psad  \
# count   1500.000000  1.500000e+03  1500.000000  1460.000000  1049.000000
# mean   10735.602667  1.000750e+06    65.595333    11.932397     0.224662
# std      425.311791  4.331570e+02     7.191527    14.939071     0.404288
# min    10000.000000  1.000000e+06    35.000000     0.100000     0.010000
# 25%    10368.750000  1.000375e+06    61.000000     5.882500     0.090000
# 50%    10733.500000  1.000750e+06    66.000000     8.500000     0.140000
# 75%    11101.250000  1.001124e+06    70.000000    13.000000     0.220000
# max    11475.000000  1.001499e+06    92.000000   224.000000     7.000000
#
#        prostate_volume    case_ISUP
# count      1473.000000  1500.000000
# mean         65.045472     0.942000
# std          36.449618     1.333099
# min           4.000000     0.000000
# 25%          40.000000     0.000000
# 50%          57.000000     0.000000
# 75%          80.000000     2.000000
# ...

# %% [markdown]
# ## case_ISUP

# %%
isup_counts = df['case_ISUP'].value_counts().reindex(range(6), fill_value=0)

fig, ax = plt.subplots(figsize=(8, 6))
isup_counts.plot(kind='bar', color='gray', edgecolor='black', ax=ax)

ax.set_title('Distribución de case_ISUP', fontsize=14)
ax.set_xlabel('Case ISUP', fontsize=12, labelpad=10)
ax.set_ylabel('Frecuencia', fontsize=12, labelpad=10)
ax.set_xticks(range(len(isup_counts)))
ax.set_xticklabels([str(i) for i in range(6)], rotation=0, fontsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(top=False, right=False, which='both')

fig.tight_layout()
# plt.savefig('distribucion_case_ISUP.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
isup_counts
# Out:
# case_ISUP
# 0    847
# 1    228
# 2    234
# 3     99
# 4     40
# 5     52
# Name: count, dtype: int64

# %% [markdown]
# ## case_csPCa

# %%
csPCa_counts = df['case_csPCa'].value_counts()

fig, ax = plt.subplots(figsize=(8, 6))
csPCa_counts.plot(kind='bar', color='gray', edgecolor='black', ax=ax)

ax.set_title('Distribución de csPCa', fontsize=14, weight='bold', pad=15)
ax.set_xlabel('csPCa', fontsize=12, weight='bold', labelpad=10)
ax.set_ylabel('Frecuencia', fontsize=12, weight='bold', labelpad=10)
ax.set_xticks(range(len(csPCa_counts)))
ax.set_xticklabels(['No', 'Sí'], rotation=0, fontsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(top=False, right=False, which = 'both')

fig.tight_layout()
# plt.savefig('distribucion_csPCa.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
csPCa_counts
# Out:
# case_csPCa
# NO     1075
# YES     425
# Name: count, dtype: int64

# %% [markdown]
# ## age

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['patient_age'].dropna(), bins=20, color='gray', edgecolor='black') # , alpha=0.8

ax.set_title('Distribución de la Edad', fontsize=14, weight='bold', pad=15)
ax.set_xlabel('Edad', fontsize=12, weight='bold', labelpad=10)
ax.set_ylabel('Frecuencia', fontsize=12, weight='bold', labelpad=10)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(top=False, right=False, which = 'both')

fig.tight_layout()
# plt.savefig('distribucion_edad.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## prostate_volume

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(df['prostate_volume'].dropna(), bins=20, color='gray', edgecolor='black') # , alpha=0.8

ax.set_title('Distribución del volumen de la próstata', fontsize=14, weight='bold', pad=15)
ax.set_xlabel('Volumen de la próstata', fontsize=12, weight='bold', labelpad=10)
ax.set_ylabel('Frecuencia', fontsize=12, weight='bold', labelpad=10)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(top=False, right=False, which = 'both')

fig.tight_layout()
# plt.savefig('distribucion_volumen_prostata.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ISUP vs volumen

# %%
mpl.rcParams.update({
    "text.usetex": True,
    "font.size": 12,
    "axes.titlesize": 14,
    "axes.labelsize": 12,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "legend.fontsize": 10,
    "text.latex.preamble": r"\usepackage[utf8]{inputenc} \usepackage{lmodern} \usepackage[spanish]{babel}" 
})

fig, ax = plt.subplots(figsize=(8, 6))

sns.scatterplot(
    x=df['case_ISUP'],
    y=df['prostate_volume'],
    ax=ax,
    color='blue',
    alpha=0.6,
    edgecolor='black'
)

sns.boxplot(
    x=df['case_ISUP'],
    y=df['prostate_volume'],
    ax=ax,
    showmeans=True,
    meanline=True,
    meanprops={"color": "red", "linewidth": 1.5, "linestyle": "--"},
    medianprops={"color": "black", "linewidth": 1.5},
    whiskerprops={"linewidth": 1.2},
    boxprops={"facecolor": "gray", "alpha": 0.4, "edgecolor": "black"}
)

ax.set_title(r'Relación entre Case ISUP y Volumen de la Próstata', pad=15)
ax.set_xlabel(r'Case ISUP', labelpad=10)
ax.set_ylabel(r'Volumen de la Próstata (ml)', labelpad=10)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.grid(axis='y', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
# plt.savefig("scatter_box_scienceplots.png", dpi=300)
plt.show()

# %% [markdown]
# # GS vs ISUP
